# %%
import pandas as pd
import numpy as np
metrics = ['Accuracy', 'Precision+', 'Recall+', 'F1+', 'Precision-', 'Recall-', 'F1-']

# %%
# random split, train on original
rs_to = pd.DataFrame(data = np.array([[0.9465000033378601, 0.9442785978317261, 0.9490000009536743, 0.9466334123437856, 0.9487437185929648, 0.944, 0.9463659147869674],
                                      [0.9269999861717224, 0.8826164603233337, 0.9850000143051147, 0.9310018816549271, 0.9830316742081447, 0.869, 0.9225053078556263],
                                      [0.9474999904632568, 0.9298751354217529, 0.9679999947547913, 0.9485546355487958, 0.9666319082377477, 0.927, 0.9464012251148545],
                                      [0.9455000162124634, 0.9222748875617981, 0.9729999899864197, 0.9469586359137774, 0.9714285714285714, 0.918, 0.9439588688946015],
                                      [0.9545000195503235, 0.9477832317352295, 0.9620000123977661, 0.9548387058905319, 0.9614213197969543, 0.947, 0.9541561712846347],
                                      [0.953499972820282, 0.9348034262657166, 0.9750000238418579, 0.9544787060104906, 0.9738766980146291, 0.932, 0.9524782830863566],
                                      [0.9509999752044678, 0.9583333134651184, 0.9430000185966492, 0.9506048383840533, 0.9438976377952756, 0.959, 0.951388888888889],
                                      [0.9459999799728394, 0.9272030591964722, 0.9679999947547913, 0.947162421005567, 0.9665271966527197, 0.924, 0.9447852760736196],
                                      [0.9509999752044678, 0.9492031931877136, 0.953000009059906, 0.9510978118833253, 0.9528112449799196, 0.949, 0.9509018036072143],
                                      [0.9455000162124634, 0.9230769276618958, 0.972000002861023, 0.946906969186448, 0.9704329461457233, 0.919, 0.9440164355418592]
                                     ]), columns = metrics)
rs_to['group'] = 'random split, train on original'

# random split, train on shuffled
rs_ts = pd.DataFrame(data = np.array([[0.8934999704360962, 0.8593607544898987, 0.9409999847412109, 0.8983293617117518, 0.9348066298342541, 0.846, 0.8881889763779527],
                                      [0.9179999828338623, 0.9130434989929199, 0.9240000247955322, 0.9184890883467274, 0.9230769230769231, 0.912, 0.9175050301810865],
                                      [0.9035000205039978, 0.9315508008003235, 0.8709999918937683, 0.9002583929776822, 0.8788732394366198, 0.936, 0.9065375302663439],
                                      [0.9154999852180481, 0.9022265076637268, 0.9319999814033508, 0.9168716005098024, 0.9296794208893485, 0.899, 0.9140823589222167],
                                      [0.9235000014305115, 0.8917669057846069, 0.9639999866485596, 0.9264776613649478, 0.9608269858541894, 0.883, 0.9202709744658676],
                                      [0.9135000109672546, 0.8949379324913025, 0.9369999766349792, 0.9154860736890864, 0.9338929695697796, 0.89, 0.9114183307731695],
                                      [0.9039999842643738, 0.9261603355407715, 0.878000020980835, 0.9014373817682054, 0.8840304182509505, 0.93, 0.9064327485380117],
                                      [0.8955000042915344, 0.8919722437858582, 0.8999999761581421, 0.8959681285305682, 0.8990918264379415, 0.891, 0.8950276243093923],
                                      [0.9035000205039978, 0.8991097807884216, 0.9089999794960022, 0.9040278308909374, 0.9079878665318504, 0.898, 0.9029663147310206],
                                      [0.908274233341217, 0.940464198589325, 0.873477041721344, 0.905733733566746, 0.8798932384341637, 0.9437022900763359, 0.9106813996316759],
                                      [0.914893627166748, 0.8882042169570923, 0.9500941634178162, 0.9181073665330891, 0.9458631256384066, 0.879392212725546, 0.9114173228346456]
                                     ]), columns = metrics)
brs_ts['group'] = 'balanced random split, train on shuffled'

# %%
all_stats = pd.concat([rs_to, rs_ts, cs_to, cs_ts], ignore_index=True)
all_stats = pd.melt(all_stats, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')
all_stats
# Out:
#                                    group   metrics  performance
# 0        random split, train on original  Accuracy     0.946500
# 1        random split, train on original  Accuracy     0.927000
# 2        random split, train on original  Accuracy     0.947500
# 3        random split, train on original  Accuracy     0.945500
# 4        random split, train on original  Accuracy     0.954500
# ..                                   ...       ...          ...
# 275  split by country, train on shuffled       F1-     0.568120
# 276  split by country, train on shuffled       F1-     0.624079
# 277  split by country, train on shuffled       F1-     0.655340
# 278  split by country, train on shuffled       F1-     0.641609
# 279  split by country, train on shuffled       F1-     0.633564
#
# [280 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(13, 6), dpi=80)
sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats, ax=ax, palette="Paired")
ax.set_title('RoBERTa 10-Fold Performance Comparison')
plt.legend(loc='best')
# sns.despine(offset=10, trim=True)
plt.show()

# %%
all_stats = pd.concat([rs_to, brs_to], ignore_index=True)
all_stats = pd.melt(all_stats, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')
all_stats
# Out:
#                                         group   metrics  performance
# 0             random split, train on original  Accuracy     0.946500
# 1             random split, train on original  Accuracy     0.927000
# 2             random split, train on original  Accuracy     0.947500
# 3             random split, train on original  Accuracy     0.945500
# 4             random split, train on original  Accuracy     0.954500
# ..                                        ...       ...          ...
# 135  balanced random split, train on original       F1-     0.958240
# 136  balanced random split, train on original       F1-     0.955801
# 137  balanced random split, train on original       F1-     0.958773
# 138  balanced random split, train on original       F1-     0.958662
# 139  balanced random split, train on original       F1-     0.952469
#
# [140 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats, ax=ax, palette="Set2")
ax.set_title('RoBERTa 10-Fold Performance Comparison (Train on Original)')
ax.set_ylim(0.86, 1)
plt.legend(loc='best')
# sns.despine(offset=10, trim=True)
plt.show()

# %%
all_stats = pd.concat([rs_ts, brs_ts], ignore_index=True)
all_stats = pd.melt(all_stats, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')
all_stats
# Out:
#                                         group   metrics  performance
# 0             random split, train on shuffled  Accuracy     0.893500
# 1             random split, train on shuffled  Accuracy     0.918000
# 2             random split, train on shuffled  Accuracy     0.903500
# 3             random split, train on shuffled  Accuracy     0.915500
# 4             random split, train on shuffled  Accuracy     0.923500
# ..                                        ...       ...          ...
# 135  balanced random split, train on shuffled       F1-     0.884332
# 136  balanced random split, train on shuffled       F1-     0.916588
# 137  balanced random split, train on shuffled       F1-     0.924809
# 138  balanced random split, train on shuffled       F1-     0.910681
# 139  balanced random split, train on shuffled       F1-     0.911417
#
# [140 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats, ax=ax, palette="Set2")
ax.set_title('RoBERTa 10-Fold Performance Comparison (Train on Shuffled)')
ax.set_ylim(0.86, 1)
plt.legend(loc='best')
# sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# ## All Model Performance Comparison
# ### Random Spllit

# %%
rs_lr_to = pd.DataFrame(data = np.array([[0.9539999961853027, 0.9809321761131287, 0.9259999990463257, 0.9526748837507167, 0.9299242424242424, 0.982, 0.9552529182879378],
                                      [0.9369999766349792, 0.9739696383476257, 0.8980000019073486, 0.9344432925469219, 0.9053803339517625, 0.976, 0.9393647738209817],
                                      [0.9334999918937683, 0.9790055155754089, 0.8859999775886536, 0.9301837104912767, 0.8958904109589041, 0.981, 0.9365155131264916],
                                      [0.9319999814033508, 0.9655172228813171, 0.8960000276565552, 0.9294605872221436, 0.9029850746268657, 0.968, 0.9343629343629344],
                                      [0.949999988079071, 0.9620122909545898, 0.9369999766349792, 0.9493414124082247, 0.9385964912280702, 0.963, 0.9506416584402763],
                                      [0.9545000195503235, 0.9586276412010193, 0.949999988079071, 0.9542943146607797, 0.9504459861248761, 0.959, 0.9547038327526132],
                                      [0.9294999837875366, 0.8929551839828491, 0.9760000109672546, 0.9326325978443748, 0.9735391400220507, 0.883, 0.9260618772941793],
                                      [0.9340000152587891, 0.9686825275421143, 0.8970000147819519, 0.9314641926615262, 0.904096834264432, 0.971, 0.9363548698167793],
                                      [0.9490000009536743, 0.9563007950782776, 0.9409999847412109, 0.9485886931035602, 0.9419291338582677, 0.957, 0.9494047619047619],
                                      [0.9449999928474426, 0.9754273295402527, 0.9129999876022339, 0.9431818018018381, 0.918233082706767, 0.977, 0.9467054263565892]]), columns = metrics)
rs_lr_to['group'] = 'LogisticRegression, train on original'

rs_xgb_to = pd.DataFrame(data = np.array([[0.9475, 0.9470529470529471, 0.948, 0.9475262368815592, 0.9479479479479479, 0.947, 0.9474737368684342],
                                      [0.9455, 0.953204476093591, 0.937, 0.9450327786182552, 0.9380530973451328, 0.954, 0.945959345562717],
                                      [0.9485, 0.9498495486459378, 0.947, 0.9484226339509263, 0.9471585244267199, 0.95, 0.9485771342985521],
                                      [0.9425, 0.9547790339157246, 0.929, 0.9417131272174355, 0.9308666017526777, 0.956, 0.9432659102121361],
                                      [0.9515, 0.9492537313432836, 0.954, 0.9516209476309226, 0.9537688442211055, 0.949, 0.9513784461152882],
                                      [0.9525, 0.9566094853683148, 0.948, 0.9522852837769965, 0.9484638255698712, 0.957, 0.9527127924340467],
                                      [0.9465, 0.9442786069651742, 0.949, 0.9466334164588529, 0.9487437185929648, 0.944, 0.9463659147869674],
                                      [0.8834999799728394, 0.9294512867927551, 0.8299999833106995, 0.8769149400548438, 0.8464317976513098, 0.937, 0.8894162316089226]]), columns = metrics)
rs_lr_ts['group'] = 'LogisticRegression, train on shuffled'

rs_xgb_ts = pd.DataFrame(data = np.array([[0.9095, 0.9107321965897693, 0.908, 0.9093640460691037, 0.9082751744765702, 0.911, 0.90963554667998],
                                      [0.906, 0.9084507042253521, 0.903, 0.9057171514543632, 0.9035785288270378, 0.909, 0.9062811565304087],
                                      [0.895, 0.8887795275590551, 0.903, 0.8958333333333334, 0.9014227642276422, 0.887, 0.8941532258064515],
                                      [0.9095, 0.9066534260178749, 0.913, 0.9098156452416543, 0.9123867069486404, 0.906, 0.9091821374811841],
                                      [0.9135, 0.913086913086913, 0.914, 0.9135432283858069, 0.913913913913914, 0.913, 0.913456728364182],
                                      [0.9045, 0.9016881827209533, 0.908, 0.9048330842052815, 0.9073514602215509, 0.901, 0.9041645760160562],
                                      [0.895, 0.8903162055335968, 0.901, 0.8956262425447316, 0.8997975708502024, 0.889, 0.8943661971830986],
                                      [0.9125, 0.9112662013958126, 0.914, 0.9126310534198703, 0.9137412236710131, 0.911, 0.9123685528292439],
                                      [0.9215, 0.9120234604105572, 0.933, 0.9223924864063273, 0.9314227226202662, 0.91, 0.9205867475973697],
                                      [0.903, 0.899009900990099, 0.908, 0.9034825870646767, 0.907070707070707, 0.898, 0.9025125628140703]]), columns = metrics)
rs_xgb_ts['group'] = 'XGBoost, train on shuffled'

rs_svm_ts = pd.DataFrame(data = np.array([[0.925, 0.9267068273092369, 0.923, 0.9248496993987976, 0.9233067729083665, 0.927, 0.9251497005988024],
                                      [0.912, 0.9071146245059288, 0.918, 0.9125248508946322, 0.917004048582996, 0.906, 0.9114688128772637],
                                      [0.8965, 0.8937437934458788, 0.9, 0.8968609865470851, 0.8992950654582075, 0.893, 0.8961364776718515],
                                      [0.911, 0.9005847953216374, 0.924, 0.912142152023692, 0.9219712525667351, 0.898, 0.9098277608915907],
                                      [0.914, 0.9207317073170732, 0.906, 0.9133064516129032, 0.90748031496063, 0.922, 0.9146825396825398],
                                      [0.9145, 0.9116186693147964, 0.918, 0.9147982062780269, 0.9174219536757301, 0.911, 0.9141996989463121],
                                      [0.905, 0.905, 0.905, 0.905, 0.905, 0.905, 0.905],
                                      [0.915, 0.9076620825147348, 0.924, 0.9157581764122895, 0.9226069246435845, 0.906, 0.9142280524722503],
                                      [0.9275, 0.9138431752178122, 0.944, 0.9286768322675848, 0.9420889348500517, 0.911, 0.9262836807320795],
                                      [0.9095, 0.9026548672566371, 0.918, 0.9102627664848786, 0.9165818921668362, 0.901, 0.908724155320222]]), columns = metrics)
rs_svm_ts['group'] = 'SVM, train on shuffled'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

all_stats_lr = pd.concat([rs_lr_to, rs_lr_ts], ignore_index=True)
all_stats_lr = pd.melt(all_stats_lr, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_xgb = pd.concat([rs_xgb_to, rs_xgb_ts], ignore_index=True)
all_stats_xgb = pd.melt(all_stats_xgb, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_svm = pd.concat([rs_svm_to, rs_svm_ts], ignore_index=True)
all_stats_svm = pd.melt(all_stats_svm, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')


sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(21, 5), ncols=3, dpi=100, sharey=True)
sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_lr, ax=ax[0], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_xgb, ax=ax[1], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_svm, ax=ax[2], palette="Paired")

ax[0].set_title('Logistic Regression')
ax[1].set_title('XGBoost')
ax[2].set_title('SVM')
plt.suptitle('Model 10-Fold Performance Comparison (RandomSplit)')

for i in ax:
    i.set_ylim(0.5, 1)
    i.legend(loc='lower right')

plt.subplots_adjust(wspace=0.05, hspace=0.05)
plt.show()

# %% [markdown]
# ### Split by Country

# %%
sc_lr_to = pd.DataFrame(data = np.array([[0.6765000224113464, 0.6544181704521179, 0.7480000257492065, 0.6980867899102214, 0.705950991831972, 0.605, 0.6515885837372105],
                                      [0.6535000205039978, 0.6795321702957153, 0.5809999704360962, 0.6264150799407273, 0.634061135371179, 0.726, 0.6769230769230768],
                                      [0.7129999995231628, 0.6521428823471069, 0.9129999876022339, 0.7608333461814452, 0.855, 0.513, 0.64125],
                                      [0.6980000138282776, 0.6809871792793274, 0.7450000047683716, 0.7115568183021321, 0.7185430463576159, 0.651, 0.683105981112277],
                                      [0.6850000023841858, 0.69111567735672, 0.6690000295639038, 0.6798780518909281, 0.6792635658914729, 0.701, 0.6899606299212597],
                                      [0.6804999709129333, 0.6814070343971252, 0.6779999732971191, 0.6796992343144239, 0.6796019900497512, 0.683, 0.6812967581047381],
                                      [0.7229999899864197, 0.656162440776825, 0.9369999766349792, 0.7718286408933218, 0.8898601398601399, 0.509, 0.6475826972010179],
                                      [0.6629999876022339, 0.676025927066803, 0.6259999871253967, 0.6500519183641734, 0.6517690875232774, 0.7, 0.6750241080038571],
                                      [0.7195000052452087, 0.6644194722175598, 0.8870000243186951, 0.7597430473583299, 0.8300751879699249, 0.552, 0.6630630630630631],
                                      [0.6949999928474426, 0.6652542352676392, 0.7850000262260437, 0.7201834960915343, 0.7378048780487805, 0.605, 0.6648351648351648]]), columns = metrics)
sc_lr_to['group'] = 'LogisticRegression, train on original'

sc_xgb_to = pd.DataFrame(data = np.array([[0.679, 0.6559233449477352, 0.753, 0.7011173184357542, 0.710093896713615, 0.605, 0.6533477321814255],
                                      [0.714, 0.6739837398373983, 0.829, 0.7434977578475335, 0.7779220779220779, 0.599, 0.6768361581920904],
                                      [0.6955, 0.652615144418423, 0.836, 0.7330118369136344, 0.7719054242002782, 0.555, 0.6457242582897034],
                                      [0.707, 0.6745362563237775, 0.8, 0.7319304666056726, 0.7542997542997543, 0.614, 0.6769570011025359],
                                      [0.6855, 0.6725581395348837, 0.723, 0.6968674698795181, 0.7005405405405405, 0.648, 0.6732467532467532],
                                      [0.7165, 0.6781893004115226, 0.824, 0.7440180586907449, 0.7757961783439491, 0.609, 0.6823529411764706],
                                      [0.7285, 0.6862265688671557, 0.842, 0.756174225415357, 0.795601552393273, 0.615, 0.6937394247038917],
                                      [0.729, 0.6805993690851735, 0.863, 0.7610229276895942, 0.8128415300546448, 0.595, 0.6870669745958429],
                                      [0.7245, 0.6794564348521183, 0.85, 0.7552199022656596, 0.7997329773030708, 0.599, 0.6849628359062321],
                                      [0.701, 0.6680602006688964, 0.799, 0.7276867030965392, 0.75, 0.603, 0.6685144124168514]]), columns = metrics)
sc_xgb_to['group'] = 'XGBoost, train on original'

sc_svm_to = pd.DataFrame(data = np.array([[0.677, 0.6523235800344234, 0.758, 0.7012025901942646, 0.711217183770883, 0.596, 0.6485310119695321],
                                      [0.721, 0.6823432343234324, 0.827, 0.7477396021699819, 0.7804568527918782, 0.615, 0.6879194630872483],
                                      [0.7205, 0.6646751306945482, 0.89, 0.7610089781958101, 0.8335854765506808, 0.551, 0.6634557495484649],
                                      [0.7285, 0.6908939014202172, 0.827, 0.752844788347747, 0.7845579078455791, 0.63, 0.6988352745424294],
                                      [0.6885, 0.6779981114258735, 0.718, 0.697425934919864, 0.7003188097768331, 0.659, 0.6790314270994333],
                                      [0.7335, 0.6834249803613511, 0.87, 0.7655081390233172, 0.8211829436038515, 0.597, 0.6913723219455704],
                                      [0.7205, 0.6802943581357318, 0.832, 0.7485380116959064, 0.7837837837837838, 0.609, 0.6854248733821047],
                                      [0.736, 0.6900161030595813, 0.857, 0.7644959857270294, 0.8113456464379947, 0.615, 0.6996587030716723],
                                      [0.7285, 0.6853203568532036, 0.845, 0.7568293775190327, 0.7979139504563233, 0.612, 0.6926994906621391],
                                      [0.702, 0.6717687074829932, 0.79, 0.7261029411764707, 0.7451456310679612, 0.614, 0.6732456140350876]]), columns = metrics)
sc_svm_to['group'] = 'SVM, train on original'


# Random Split, train on shuffled
sc_lr_ts = pd.DataFrame(data = np.array([[0.7080000042915344, 0.6524926424026489, 0.8899999856948853,0.7529610603333862, 0.8270440251572327, 0.526, 0.6430317848410758],
                                      [0.718500018119812, 0.6503785252571106, 0.9449999928474426, 0.7704851165305981, 0.8994515539305301, 0.492, 0.6360698125404007],
                                      [0.6784999966621399, 0.6553524732589722, 0.753000020980835, 0.7007910706051134, 0.7097532314923619, 0.604, 0.6526202052944354],
                                      [0.7350000143051147, 0.6961602568626404, 0.8339999914169312, 0.758871691904221, 0.7930174563591023, 0.636, 0.7058823529411765],
                                      [0.6940000057220459, 0.6501547694206238, 0.8399999737739563, 0.7329842645624146, 0.7740112994350282, 0.548, 0.6416861826697893],
                                      [0.7325000166893005, 0.6757369637489319, 0.8939999938011169, 0.7696943599335108, 0.843426883308715, 0.571, 0.6809779367918903],
                                      [0.6875, 0.667560338973999, 0.746999979019165, 0.7050495519555693, 0.7128263337116912, 0.628, 0.6677299308878256],
                                      [0.7455000281333923, 0.6904577016830444, 0.8899999856948853, 0.7776321372327734, 0.8452883263009845, 0.601, 0.7025131502045587],
                                      [0.671500027179718, 0.6196789741516113, 0.8880000114440918, 0.7299629979532722, 0.8024691358024691, 0.455, 0.5807275047862157],
                                      [0.7214999794960022, 0.6627479791641235, 0.9020000100135803, 0.7640830190894456, 0.8466353677621283, 0.541, 0.6601586333129958]]), columns = metrics)
sc_lr_ts['group'] = 'LogisticRegression, train on shuffled'

sc_xgb_ts = pd.DataFrame(data = np.array([[0.688, 0.6525974025974026, 0.804, 0.7204301075268817, 0.7447916666666666, 0.572, 0.6470588235294118],
                                      [0.715, 0.6771004942339374, 0.822, 0.7425474254742548, 0.7735368956743003, 0.608, 0.6808510638297873],
                                      [0.6845, 0.6493927125506073, 0.802, 0.7176733780760627, 0.7411764705882353, 0.567, 0.6424929178470256],
                                      [0.6925, 0.6586974443528442, 0.799, 0.7220967013104383, 0.7445997458703939, 0.586, 0.6558477895914941],
                                      [0.6815, 0.6437054631828979, 0.813, 0.7185152452496686, 0.746268656716418, 0.55, 0.6332757628094415],
                                      [0.709, 0.6622670807453416, 0.853, 0.7456293706293706, 0.7935393258426966, 0.565, 0.6600467289719626],
                                      [0.7, 0.6584786053882726, 0.831, 0.7347480106100797, 0.7710027100271003, 0.569, 0.6547756041426926],
                                      [0.726, 0.6810897435897436, 0.85, 0.7562277580071174, 0.800531914893617, 0.602, 0.687214611872146],
                                      [0.667, 0.6235207100591716, 0.843, 0.7168367346938775, 0.7577160493827161, 0.491, 0.595873786407767],
                                      [0.6975, 0.6488319517709118, 0.861, 0.740008594757198, 0.7934621099554234, 0.534, 0.638374178123132]]), columns = metrics)
sc_xgb_ts['group'] = 'XGBoost, train on shuffled'

sc_svm_ts = pd.DataFrame(data = np.array([[0.6935, 0.6455981941309256, 0.858, 0.7367969085444397, 0.7883755588673621, 0.529, 0.6331538001196888],
                                      [0.716, 0.6653905053598775, 0.869, 0.753686036426713, 0.8112391930835735, 0.563, 0.6646989374262101],
                                      [0.693, 0.6486902927580893, 0.842, 0.7328111401218451, 0.7749287749287749, 0.544, 0.6392479435957696],
                                      [0.7275, 0.6863226863226863, 0.838, 0.754615038271049, 0.79204107830552, 0.617, 0.6936481169196177],
                                      [0.693, 0.6480061349693251, 0.845, 0.7335069444444444, 0.7772988505747126, 0.541, 0.6379716981132075],
                                      [0.737, 0.6848673946957878, 0.878, 0.7695004382120947, 0.83008356545961, 0.596, 0.6938300349243306],
                                      [0.71, 0.661042944785276, 0.862, 0.7482638888888888, 0.8017241379310345, 0.558, 0.6580188679245284],
                                      [0.7415, 0.6906077348066298, 0.875, 0.771945302161447, 0.8294679399727148, 0.608, 0.701673398730525],
                                      [0.6755, 0.6306775874906925, 0.847, 0.7230046948356808, 0.7671232876712328, 0.504, 0.6083283041641521],
                                      [0.707, 0.6556390977443609, 0.872, 0.7484978540772533, 0.808955223880597, 0.542, 0.6491017964071857]]), columns = metrics)
sc_svm_ts['group'] = 'SVM, train on shuffled'

# %% [markdown]
# ## Country Balanced Random Split

# %%
cb_lr_to = pd.DataFrame(data = np.array([[0.9456264972686768, 0.9826353192329407, 0.9075471758842468, 0.9435997965251304, 0.9137323943661971, 0.9838862559241706, 0.947512551346417],
                                      [0.9527186751365662, 0.9413854479789734, 0.9689213633537292, 0.9549549488972534, 0.9656218402426694, 0.9353574926542605, 0.9502487562189055],
                                      [0.9470449090003967, 0.92328280210495, 0.9754948019981384, 0.9486709473309715, 0.9738430583501007, 0.9184060721062619, 0.9453125],
                                      [0.9565011858940125, 0.9480642080307007, 0.9644572734832764, 0.9561904846585525, 0.9649621212121212, 0.9487895716945997, 0.9568075117370892],
                                      [0.9460992813110352, 0.9574056267738342, 0.9338998794555664, 0.9455066846569153, 0.9353049907578558, 0.9583333333333334, 0.9466791393826006],
                                      [0.944208025932312, 0.9151356220245361, 0.9803186655044556, 0.946606349349864, 0.9783950617283951, 0.9074427480916031, 0.9415841584158415],
                                      [0.9498817920684814, 0.9619619846343994, 0.933916449546814, 0.9477317797296008, 0.9390681003584229, 0.9650092081031307, 0.9518619436875567],
                                      [0.9569739699363708, 0.9537299275398254, 0.9600760340690613, 0.9568924590825739, 0.9602272727272727, 0.9539040451552211, 0.9570552147239264],
                                      [0.9408983588218689, 0.97773277759552, 0.9036482572555542, 0.9392318771893668, 0.9086069210292813, 0.9789674952198852, 0.9424758398527382],
                                      [0.9550827145576477, 0.9554924368858337, 0.9545884728431702, 0.9550402409596913, 0.9546742209631728, 0.9555765595463138, 0.9551251771374586]]), columns = metrics)
cb_lr_to['group'] = 'LogisticRegression, train on original'

cb_xgb_to = pd.DataFrame(data = np.array([[0.9555555555555556, 0.9530956848030019, 0.9584905660377359, 0.9557855126999059, 0.9580552907530981, 0.95260663507109, 0.9553231939163498],
                                      [0.9508274231678487, 0.9541284403669725, 0.9506398537477148, 0.9523809523809523, 0.9473170731707317, 0.951028403525955, 0.949169110459433],
                                      [0.956501182033097, 0.9498607242339833, 0.9641847313854854, 0.9569691300280637, 0.9633911368015414, 0.9487666034155597, 0.9560229445506693],
                                      [0.956501182033097, 0.9566891241578441, 0.9548511047070125, 0.9557692307692308, 0.9563197026022305, 0.9581005586592178, 0.9572093023255814],
                                      [0.9574468085106383, 0.9540768509840675, 0.9612842304060434, 0.9576669802445906, 0.9608778625954199, 0.9535984848484849, 0.9572243346007604],
                                      [0.9569739952718677, 0.9501845018450185, 0.9653233364573571, 0.9576940957694096, 0.9641125121241513, 0.9484732824427481, 0.9562289562289562],
                                      [0.9583924349881797, 0.9528392685274302, 0.9620991253644315, 0.9574468085106383, 0.9637546468401487, 0.9548802946593001, 0.9592969472710453],
                                      [0.9583924349881797, 0.9564393939393939, 0.9600760456273765, 0.9582542694497154, 0.9603399433427762, 0.9567262464722484, 0.9585296889726672],
                                      [0.956501182033097, 0.9710703953712633, 0.9420018709073901, 0.9563152896486229, 0.9424860853432282, 0.97131931166348, 0.9566854990583804],
                                      [0.9621749408983451, 0.9692603266090298, 0.9545884578997161, 0.9618684461391802, 0.9553072625698324, 0.9697542533081286, 0.9624765478424014]]), columns = metrics)
cb_xgb_to['group'] = 'XGBoost, train on original'

cb_svm_to = pd.DataFrame(data = np.array([[0.9612293144208038, 0.9561567164179104, 0.9669811320754716, 0.9615384615384615, 0.9664429530201343, 0.9554502369668246, 0.9609151572926597],
                                      [0.9602836879432625, 0.9658671586715867, 0.9570383912248629, 0.9614325068870524, 0.9544131910766246, 0.9637610186092067, 0.9590643274853801],
                                      [0.9602836879432625, 0.9535747446610956, 0.9679547596606974, 0.9607109448082319, 0.9672447013487476, 0.952561669829222, 0.9598470363288719],
                                      [0.9640661938534278, 0.9599618684461392, 0.9673390970220941, 0.9636363636363637, 0.9681050656660413, 0.9608938547486033, 0.9644859813084112],
                                      [0.9560283687943263, 0.9539473684210527, 0.9584513692162417, 0.9561940650023552, 0.9581351094196003, 0.9535984848484849, 0.955861414333175],
                                      [0.9588652482269504, 0.9553903345724907, 0.9634489222118088, 0.9594027064862343, 0.9624639076034649, 0.9541984732824428, 0.9583133684714902],
                                      [0.9607565011820332, 0.9548076923076924, 0.9650145772594753, 0.9598840019333013, 0.9665116279069768, 0.9567219152854513, 0.961591855622397],
                                      [0.9640661938534278, 0.9612476370510397, 0.9667300380228137, 0.9639810426540284, 0.9668874172185431, 0.9614299153339605, 0.9641509433962264],
                                      [0.9593380614657211, 0.9667616334283001, 0.9522918615528532, 0.9594721960414704, 0.9519774011299436, 0.9665391969407265, 0.9592030360531308],
                                      [0.9631205673758865, 0.9622285174693107, 0.9640491958372753, 0.9631379962192818, 0.9640151515151515, 0.9621928166351607, 0.9631031220435194]]), columns = metrics)
cb_svm_to['group'] = 'SVM, train on original'


# Random Split, train on shuffled
cb_lr_ts = pd.DataFrame(data = np.array([[0.9106382727622986, 0.9311023354530334, 0.888262927532196, 0.90917827568558, 0.89171974522293, 0.9333333333333333, 0.9120521172638437],
                                      [0.9158392548561096, 0.9090909361839294, 0.9229305386543274, 0.9159584633057599, 0.9227099236641222, 0.9088345864661654, 0.915719696969697],
                                      [0.9248226881027222, 0.9210276007652283, 0.9272030591964722, 0.924105013009148, 0.9285714285714286, 0.9225023342670402, 0.9255269320843093],
                                      [0.9087470173835754, 0.9157581925392151, 0.895348846912384, 0.9054385233783055, 0.9023508137432188, 0.9215143120960295, 0.9118318867062585],
                                      [0.9210401773452759, 0.9072256684303284, 0.9416666626930237, 0.9241253837438721, 0.9366197183098591, 0.8995169082125604, 0.917693445046821],
                                      [0.91725768321513, 0.9172346640701071, 0.9127906976744186, 0.9150072850898495, 0.9172794117647058, 0.9215143120960295, 0.9193919852602488],
                                      [0.924822695035461, 0.9122649955237243, 0.9435185185185185, 0.9276285844333183, 0.938877755511022, 0.9053140096618357, 0.9217904574520412],
                                      [0.9125295508274232, 0.8996212121212122, 0.923226433430515, 0.9112709832134293, 0.9254013220018886, 0.9023941068139963, 0.9137529137529138],
                                      [0.9243498817966903, 0.9195837275307474, 0.9283667621776505, 0.9239543726235742, 0.9291115311909263, 0.9204119850187266, 0.9247412982126058],
                                      [0.9347517730496454, 0.9357208448117539, 0.937442502299908, 0.936580882352941, 0.9337231968810916, 0.9319066147859922, 0.9328140214216163],
                                      [0.9295508274231679, 0.9227799227799228, 0.9326829268292683, 0.9277049975739933, 0.9360518999073216, 0.926605504587156, 0.9313047487321346],
                                      [0.9271867612293144, 0.9282385834109972, 0.9282385834109972, 0.9282385834109972, 0.9261036468330134, 0.9261036468330134, 0.9261036468330134]]), columns = metrics)
cb_svm_ts['group'] = 'SVM, train on shuffled'

# %% [markdown]
# ### Plot all Linear Regression data

# %%
all_stats_rs = pd.concat([rs_lr_to, rs_lr_ts], ignore_index=True)
all_stats_rs = pd.melt(all_stats_rs, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_sc = pd.concat([sc_lr_to, sc_lr_ts], ignore_index=True)
all_stats_sc = pd.melt(all_stats_sc, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_cb = pd.concat([cb_lr_to, cb_lr_ts], ignore_index=True)
all_stats_cb = pd.melt(all_stats_cb, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

fig, ax = plt.subplots(figsize=(21, 4), ncols=3, dpi=100, sharey=True)

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_rs, ax=ax[0], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_sc, ax=ax[1], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_cb, ax=ax[2], palette="Paired")

ax[0].set_title('Random Split')
ax[1].set_title('Split by Country')
ax[2].set_title('Country-Balanced Random Split')
ax[0].set_ylabel('Performance (LogisticRegression)')
for i in [1, 2]:
    ax[i].set_ylabel('')
    
plt.suptitle('Model 10-Fold Performance Comparison')

for i in ax:
    i.set_xticks([])
    i.set_xlabel('')
    i.set_ylim(0.5, 1)
    i.legend(loc='lower left')

plt.subplots_adjust(wspace=0.01, hspace=0.01)
plt.show()

# %% [markdown]
# ### Plot all XGBoost data

# %%
all_stats_rs = pd.concat([rs_xgb_to, rs_xgb_ts], ignore_index=True)
all_stats_rs = pd.melt(all_stats_rs, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_sc = pd.concat([sc_xgb_to, sc_xgb_ts], ignore_index=True)
all_stats_sc = pd.melt(all_stats_sc, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_cb = pd.concat([cb_xgb_to, cb_xgb_ts], ignore_index=True)
all_stats_cb = pd.melt(all_stats_cb, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

fig, ax = plt.subplots(figsize=(21, 4), ncols=3, dpi=100, sharey=True)

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_rs, ax=ax[0], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_sc, ax=ax[1], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_cb, ax=ax[2], palette="Paired")

# ax[0].set_title('Random Split')
# ax[1].set_title('Split by Country')
# ax[2].set_title('Country-Balanced Random Split')
ax[0].set_ylabel('Performance (XGBoost)')
for i in [1, 2]:
    ax[i].set_ylabel('')
    
# plt.suptitle('Model 10-Fold Performance Comparison (XGBoost)')

for i in ax:
    i.set_xticks([])
    i.set_xlabel('')
    i.set_ylim(0.5, 1)
    i.legend(loc='lower left')

plt.subplots_adjust(wspace=0.01, hspace=0.01)
plt.show()

# %% [markdown]
# ### Plot all SVM data

# %%
all_stats_rs = pd.concat([rs_svm_to, rs_svm_ts], ignore_index=True)
all_stats_rs = pd.melt(all_stats_rs, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_sc = pd.concat([sc_svm_to, sc_svm_ts], ignore_index=True)
all_stats_sc = pd.melt(all_stats_sc, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

all_stats_cb = pd.concat([cb_svm_to, cb_svm_ts], ignore_index=True)
all_stats_cb = pd.melt(all_stats_cb, 
                    id_vars=['group'], 
                    value_vars=metrics,
                    var_name='metrics',
                    value_name='performance')

fig, ax = plt.subplots(figsize=(21, 4), ncols=3, dpi=100, sharey=True)

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_rs, ax=ax[0], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_sc, ax=ax[1], palette="Paired")

sns.pointplot(x='metrics', y="performance", hue="group", 
              ci='sd', dodge=.2,
              data=all_stats_cb, ax=ax[2], palette="Paired")

# ax[0].set_title('Random Split')
# ax[1].set_title('Split by Country')
# ax[2].set_title('Country-Balanced Random Split')
# plt.suptitle('Model 10-Fold Performance Comparison (SVM)')

ax[0].set_ylabel('Performance (SVM)')
for i in [1, 2]:
    ax[i].set_ylabel('')

for i in ax:
    i.set_ylim(0.5, 1)
    i.legend(loc='lower left')

plt.subplots_adjust(wspace=0.01, hspace=0.01)
plt.show()
