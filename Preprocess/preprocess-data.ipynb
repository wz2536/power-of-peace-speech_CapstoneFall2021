# %% [markdown]
# Records generated using ml.c5.18xlarge

# %%
import numpy as np
import pandas as pd
import scipy
import time
import ujson as json
import boto3
import s3fs
from multiprocessing import Process, Manager
from multiprocessing.pool import ThreadPool, Pool

LOW_PEACE = set(['Afghanistan', 'Congo', 'Guinea',
             'India', 'Iran', 'Kenya', 'Nigeria',
             'Sri Lanka', 'Uganda', 'Zimbabwe'])
HIGH_PEACE = set(['Austria', 'Australia', 'Belgium', 
             'Czech Republic', 'Denmark', 'Finland',
             'Netherlands', 'New Zealand', 'Norway', 'Sweden'])

# Sample file
# 'peaceClassify/data/highPeace/00399ef3b93fc5251d938d2023c7bce9.json'

# %% [markdown]
# ## Load in both datasets

# %%
start_time = time.time()
hp_df = pd.read_csv('s3://compressed-data-sample/compressed1m_hp.csv', 
                          dtype={"wordCount": 'int16', "country":'category'})
end_time = time.time()
print(f'Loading Time: {end_time - start_time} seconds')
hp_df
# Out:
# Loading Time: 280.9251012802124 seconds
#                                                     title  \
# 0       MONTHLY SECTOR REPORT: S&P/ASX EMERGING COMPAN...
# 1                                 PAPRIKA CLUB RESTAURANT
# 2           Bone implants to be made from 3D printed salt
# 3       Yes, you're entitled to a free portrait of the...
# 4                   Why is Hemsworth wearing nail polish?
# ...                                                   ...
# 999995     Murder sentence cannot heal family's heartache
# 999996  Residents' satisfaction with Shellharbour coun...
# 999997  Weekly: Macmahon Holdings climbs 4.9% on weak ...
# 999998  Stock Weekly: Valoe (VALOE:6.22c) in bottom 1%...
# 999999  TAMWORTH Regional Council will support local b...
#
#                                                   content  wordCount  \
# 0       AUSTRALIAN MONTHLY INDEX REPORT\n\nThe S&P/ASX...       2405
# 1       THE Paprika Club Restaurant offers freshly pre...        120
# 2       ABSTRACT\n\n\n\nResearchers have developed a n...        545
# 3       It's a truth universally acknowledged that a h...        598
# 4       If you thought nail polish was only for women ...        729
# ...                                                   ...        ...
# 999995  The man who murdered 90-year-old Springbank gr...        621
# 999996  Shellharbour citizens' satisfaction with their...        313
# 999997  AUSTRALIAN WEEKLY STOCK REPORT\n\nMacmahon Hol...       3108
# 999998  FINNISH WEEKLY STOCK REPORT\n\nValoe Oyj (HEL:...      17401
# 999999  TAMWORTH Regional Council will support local b...        300
#
#           country
# 0       Australia
# 1       Australia
# 2       Australia
# 3       Australia
# 4       Australia
# ...           ...
# 999995  Australia
# 999996  Australia
# 999997  Australia
# 999998    Finland
# 999999  Australia
#
# [1000000 rows x 4 columns]

# %%
# Check if export correctly
start_time = time.time()
lp_df = pd.read_csv('s3://compressed-data-sample/compressed1m_lp.csv', 
                    dtype={"wordCount": 'int16', "country":'category'})
end_time = time.time()
print(f'Loading Time: {end_time - start_time} seconds')
lp_df
# Out:
# Loading Time: 150.52604365348816 seconds
#                                                     title  \
# 0       Atlas Cycles (Haryana) keeps sliding, down 10....
# 1       Varun Dhawan shares quirky boomerang to wish S...
# 2              Traffic cops launch Road Courtesy campaign
# 3       United States Courts Opinions: UNITED STATES D...
# 4       OSCE Secretary General sympathizes with Iran q...
# ...                                                   ...
# 999995  Intel Awarded Patent for Systems, Methods and ...
# 999996  Morning Alert: Williamson Magor & Co keeps ris...
# 999997  LJUBLJANSKE MLEKARNE, mlekarska industrija, d....
# 999998  STEEL AUTHORITY OF INDIA LIMITED (SAIL) Provid...
# 999999          Curaleaf's Select Brand Expands into Ohio
#
#                                                   content  wordCount country
# 0       INDIAN DAILY STOCK REPORT\n\nAtlas Cycles (Har...       1555   India
# 1       Mumbai (Maharashtra) [India], August 12 (ANI):...        177   India
# 2       Vadodara: After conducting an intense drive fo...        308   India
# 3       Washington: UNITED STATES DISTRICT COURT NORTH...       1993   India
# 4       Tehran: The official news agency of Iran (IRNA...        259    Iran
# ...                                                   ...        ...     ...
# 999995  FULL TEXT\n\n\n\nPublication Name: Software Pa...        241   India
# 999996  INDIAN INTRA-DAY STOCK REPORT\n\nWilliamson Ma...        680   India
# 999997  Slovenia, Nov. 14 -- Slovenia based LJUBLJANSK...         68   India
# 999998  India ,April  10 -- Tender No. CCNW/PR11300076...         51   India
# 999999  WAKEFIELD, Massachusetts, Oct. 5 -- Curaleaf H...        566   India
#
# [1000000 rows x 4 columns]

# %% [markdown]
# ## Prepare preprocessing

# %%
import re
import requests

# %%
! pip install spacy
! python -m spacy download en_core_web_sm
import spacy
# Out:
# Requirement already satisfied: spacy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.1.4)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (21.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (0.7.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (8.0.12)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (58.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (1.19.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (1.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->spacy) (3.0.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: dataclasses<1.0,>=0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathy>=0.3.5->spacy) (0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: contextvars<3,>=2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from thinc<8.1.0,>=8.0.12->spacy) (2.4)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.12->spacy) (0.15)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->spacy) (1.1.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 21.7 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from en-core-web-sm==3.1.0) (3.1.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.62.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.5)
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.26.0)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (58.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: dataclasses<1.0,>=0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.7)
# Requirement already satisfied: contextvars<3,>=2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from thinc<8.1.0,>=8.0.12->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.12->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.15)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.1.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
CONVERT_DICT_URL = "https://raw.githubusercontent.com/hyperreality/American-British-English-Translator/master/data/british_spellings.json"
british_to_american_dict = requests.get(CONVERT_DICT_URL).json()
REMOVED_ENTITY_TYPE = set(['PERSON', 'GPE', 'ORG'])
SENT_TO_REMOVE = re.compile('For any query with respect to this article or any other content requirement, please contact Editor at')
special_pattern = re.compile(r'(http\S+)|(\S+.com)|(\S*@\S*\s?)|\(\S+ ?: ?\S+\)', flags=re.MULTILINE)
spacy_nlp = spacy.load('en_core_web_sm',  
                       exclude=['senter', 'entity_ruler','textcat', 'sentencizer', 'merge_noun_chunks', 'tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer'])

# %%
british_pattern = '|'.join([r'\b'+word+r'\b' for word in british_to_american_dict.keys()])

def americanize(string):
    '''
    Convert all British English spelling to American spelling in the input string
    source: https://stackoverflow.com/questions/42329766/python-nlp-british-english-vs-american-english
    -- Modified the code from source to meet our special requirement here. 
    Input:
      sentence: a text string
    Return: 
      string: a string with all words in English spelling
    '''
    
    for british_word in set([i.lower() for i in re.findall(british_pattern, string, flags=re.IGNORECASE)]):
        string = re.sub(r'\b'+british_word+r'\b', british_to_american_dict[british_word], string, flags=re.IGNORECASE)
  
    return string


def preprocess(sentence):
    '''
    Preprocessing the raw text and prepare for model input
    Input:
      sentences: a series of text strings
    Return:
      sentences: A series of preprocessed sentence for BERT encoder
    '''
    # Step 1: URL and Email Removal
    # Remove the repeating phrase
    sentence = SENT_TO_REMOVE.sub(' ', sentence)
    
    # Remove website url and email address and Stock Symbols
    sentence = special_pattern.sub('', sentence)
    
    # Step 2: Convert British to American English
    sentence = americanize(sentence)
      
    # Step 3: Identify and Remove Named Entity
    # Use spacy to get a sequence of tokens for named entity removal
    sentence = ' '.join(['%s'%ent for ent in spacy_nlp(sentence) if ent.ent_type_ not in REMOVED_ENTITY_TYPE])
    
    # Step 4: Cleanup
    # Remove new line character
    sentences = re.sub('\n', ' ', sentence)
    # Remove single letter word since it doesn't make sense; might be some technical terms that are trimmed off
    sentence = re.sub('\ [a-zA-z]\ ', ' ', sentence, flags=re.IGNORECASE)
    
    # Remove redundant spaces and unnecessary spaces between punctuations and letters
    sentence = re.sub(' +', ' ', sentence)
    sentence  = re.sub(r'(\s([,.?!%"\']))|(?<=\[|\()(.*?)(?=\)|\])', lambda x: x.group().strip(), sentence)
    
    return sentence

# %% [markdown]
# ## Start Parallel Computing

# %%
! pip install pandarallel
from pandarallel import pandarallel
# Out:
# Requirement already satisfied: pandarallel in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.5.4)
# Requirement already satisfied: dill in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandarallel) (0.3.4)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
pandarallel.initialize()

time_start = time.time()
lp_df['content_cleaned'] = lp_df.parallel_apply(lambda x: preprocess(x['title'] + '\n' + x['content']), axis=1)
time_end = time.time()

print(f'Preprocessing Time: {time_end - time_start} seconds')
# Out:
# INFO: Pandarallel will run on 72 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Preprocessing Time: 1124.8846995830536 seconds

# %%
# Quick check on the result
lp_df
# Out:
#                                                     title  \
# 0       Atlas Cycles (Haryana) keeps sliding, down 10....
# 1       Varun Dhawan shares quirky boomerang to wish S...
# 2              Traffic cops launch Road Courtesy campaign
# 3       United States Courts Opinions: UNITED STATES D...
# 4       OSCE Secretary General sympathizes with Iran q...
# ...                                                   ...
# 999995  Intel Awarded Patent for Systems, Methods and ...
# 999996  Morning Alert: Williamson Magor & Co keeps ris...
# 999997  LJUBLJANSKE MLEKARNE, mlekarska industrija, d....
# 999998  STEEL AUTHORITY OF INDIA LIMITED (SAIL) Provid...
# 999999          Curaleaf's Select Brand Expands into Ohio
#
#                                                   content  wordCount country  \
# 0       INDIAN DAILY STOCK REPORT\n\nAtlas Cycles (Har...       1555   India
# 1       Mumbai (Maharashtra) [India], August 12 (ANI):...        177   India
# 2       Vadodara: After conducting an intense drive fo...        308   India
# 3       Washington: UNITED STATES DISTRICT COURT NORTH...       1993   India
# 4       Tehran: The official news agency of Iran (IRNA...        259    Iran
# ...                                                   ...        ...     ...
# 999995  FULL TEXT\n\n\n\nPublication Name: Software Pa...        241   India
# 999996  INDIAN INTRA-DAY STOCK REPORT\n\nWilliamson Ma...        680   India
# 999997  Slovenia, Nov. 14 -- Slovenia based LJUBLJANSK...         68   India
# 999998  India ,April  10 -- Tender No. CCNW/PR11300076...         51   India
# 999999  WAKEFIELD, Massachusetts, Oct. 5 -- Curaleaf H...        566   India
#
#                                           content_cleaned
# 0       (Haryana) keeps sliding, down 10.2% in 4 days ...
# 1       Varun Dhawan shares quirky to wish on birthday...
# 2       Traffic cops launch Road Courtesy campaign \n ...
# 3       : : JOEL,, v., et al., Defendants \n : has iss...
# 4       Secretary General sympathizes with quake victi...
# ...                                                   ...
# 999995  for \n FULL TEXT \n\n\n\n Publication Name : S...
# 999996  Morning Alert : keeps rising : up 22.0% in 6 d...
# 999997  LJUBLJANSKE MLEKARNE, industrija, d.o.o. bags ...
# 999998  STEEL AUTHORITY OF INDIA LIMITED (SAIL) Provid...
# 999999  's Select Brand Expands into \n,, Oct. 5 -- is...
#
# [1000000 rows x 5 columns]

# %%
pandarallel.initialize()

time_start = time.time()
hp_df['content_cleaned'] = hp_df.parallel_apply(lambda x: preprocess(x['title'] + '\n' + x['content']), axis=1)
time_end = time.time()

print(f'Preprocessing Time: {time_end - time_start} seconds')
# Out:
# INFO: Pandarallel will run on 72 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Preprocessing Time: 2308.610693216324 seconds

# %%
# Quick check on the result
hp_df
# Out:
#                                                     title  \
# 0       MONTHLY SECTOR REPORT: S&P/ASX EMERGING COMPAN...
# 1                                 PAPRIKA CLUB RESTAURANT
# 2           Bone implants to be made from 3D printed salt
# 3       Yes, you're entitled to a free portrait of the...
# 4                   Why is Hemsworth wearing nail polish?
# ...                                                   ...
# 999995     Murder sentence cannot heal family's heartache
# 999996  Residents' satisfaction with Shellharbour coun...
# 999997  Weekly: Macmahon Holdings climbs 4.9% on weak ...
# 999998  Stock Weekly: Valoe (VALOE:6.22c) in bottom 1%...
# 999999  TAMWORTH Regional Council will support local b...
#
#                                                   content  wordCount  \
# 0       AUSTRALIAN MONTHLY INDEX REPORT\n\nThe S&P/ASX...       2405
# 1       THE Paprika Club Restaurant offers freshly pre...        120
# 2       ABSTRACT\n\n\n\nResearchers have developed a n...        545
# 3       It's a truth universally acknowledged that a h...        598
# 4       If you thought nail polish was only for women ...        729
# ...                                                   ...        ...
# 999995  The man who murdered 90-year-old Springbank gr...        621
# 999996  Shellharbour citizens' satisfaction with their...        313
# 999997  AUSTRALIAN WEEKLY STOCK REPORT\n\nMacmahon Hol...       3108
# 999998  FINNISH WEEKLY STOCK REPORT\n\nValoe Oyj (HEL:...      17401
# 999999  TAMWORTH Regional Council will support local b...        300
#
#           country                                    content_cleaned
# 0       Australia  MONTHLY SECTOR REPORT : (), WITH 50 - DAY MA B...
# 1       Australia  \n offers freshly prepared, delicious and arom...
# 2       Australia  Bone implants to be made from 3D printed salt ...
# 3       Australia  Yes, you're entitled to free portrait of the Q...
# 4       Australia  Why is wearing nail polish? \n If you thought ...
# ...           ...                                                ...
# 999995  Australia  Murder sentence can not heal family's heartach...
# 999996  Australia  Residents' satisfaction with Shellharbour coun...
# 999997  Australia  Weekly : Macmahon Holdings climbs 4.9% on weak...
# 999998    Finland  : Valoe in bottom 1% performers of Finnish mar...
# 999999  Australia  will support local busin \n will support local...
#
# [1000000 rows x 5 columns]

# %% [markdown]
# ## Perform Train-Test split

# %%
from sklearn.model_selection import train_test_split
s3_resource = boto3.resource('s3')

# %%
time_start = time.time()
train_peace, test_peace = train_test_split(hp_df, test_size=0.2)
train_nonpeace, test_nonpeace = train_test_split(lp_df, test_size=0.2)

train = pd.concat([train_peace, train_nonpeace], ignore_index=True)
test = pd.concat([test_peace, test_nonpeace], ignore_index=True)
time_end = time.time()

print(f'Spliting Time: {time_end - time_start} seconds')
# Out:
# Spliting Time: 4.499696731567383 seconds

# %%
train
# Out:
#                                                      title  \
# 0        Australia: Ethicon Endo-Surgery Receives Paten...
# 1                             Even basic data offers boost
# 2        May 05, 2020: Carrier Corporation issued paten...
# 3                  Green light for traffic safety projects
# 4        John Howard and Geoffrey Blainey to open Ramsa...
# ...                                                    ...
# 1599995   Oh Hyun Junior High School Classroom Repair Work
# 1599996  Beach lifeguards spot marooned lovers kilometr...
# 1599997  Racial Justice and Civil Rights Organizations ...
# 1599998  Anhui Huiming Machinery Mfg Files Chinese Pate...
# 1599999  Transformers & Rectifiers (India) underperform...
#
#                                                    content  wordCount  \
# 0        Australia, April 18 -- Ethicon Endo-Surgery In...        118
# 1        BETTER use can be made of basic data already b...        295
# 2        Carrier Corporation has been issued a new U.S....       3444
# 3        LIVE LOCAL. LOVE LOCAL\n\nWITH AUCKLAND COUNCI...        267
# 4        Sydney, Wednesday 4 April 2018: Emeritus Profe...        479
# ...                                                    ...        ...
# 1599995  Contract awarded for Oh hyun junior high schoo...        114
# 1599996  MUMBAI: A young couple perched on the rocks by...        220
# 1599997  New York: American Civil Liberties Union has i...        468
# 1599998  FULL TEXT\n\n\n\nPublication Name: Metal & Min...        340
# 1599999  INDIAN DAILY STOCK REPORT\n\nTransformers & Re...       1431
#
#              country                                    content_cleaned
# 0          Australia  : Surgical instrument with modular end effecto...
# 1          Australia  Even basic data offers boost \n BETTER use can...
# 2          Australia  May 05, 2020 : issued patent titled" Image sen...
# 3        New Zealand  Green light for traffic safety projects \n LIV...
# 4          Australia  and to open center building \n, Wednesday 4 Ap...
# ...              ...                                                ...
# 1599995        India  Oh Hyun Junior High School Classroom Repair Wo...
# 1599996        India  Beach lifeguards spot marooned lovers kilomete...
# 1599997        India  Racial Justice and Civil Rights Organizations ...
# 1599998        India  Anhui Huiming Machinery Mfg Files Chinese Pate...
# 1599999        India  () underperforms 88% of the market July 13, 20...
#
# [1600000 rows x 5 columns]

# %%
# Export Train
train.to_csv('s3://compressed-data-sample/processed_train.csv', index=False)

# %%
# Check if export correctly
start_time = time.time()
train_check = pd.read_csv('s3://compressed-data-sample/processed_train.csv', 
                          dtype={"wordCount": 'int16', "country":'category'})
end_time = time.time()
print(f'Loading Time: {end_time - start_time} seconds')
train_check
# Out:
# Loading Time: 643.808084487915 seconds
#                                                      title  \
# 0        Australia: Ethicon Endo-Surgery Receives Paten...
# 1                             Even basic data offers boost
# 2        May 05, 2020: Carrier Corporation issued paten...
# 3                  Green light for traffic safety projects
# 4        John Howard and Geoffrey Blainey to open Ramsa...
# ...                                                    ...
# 1599995   Oh Hyun Junior High School Classroom Repair Work
# 1599996  Beach lifeguards spot marooned lovers kilometr...
# 1599997  Racial Justice and Civil Rights Organizations ...
# 1599998  Anhui Huiming Machinery Mfg Files Chinese Pate...
# 1599999  Transformers & Rectifiers (India) underperform...
#
#                                                    content  wordCount  \
# 0        Australia, April 18 -- Ethicon Endo-Surgery In...        118
# 1        BETTER use can be made of basic data already b...        295
# 2        Carrier Corporation has been issued a new U.S....       3444
# 3        LIVE LOCAL. LOVE LOCAL\n\nWITH AUCKLAND COUNCI...        267
# 4        Sydney, Wednesday 4 April 2018: Emeritus Profe...        479
# ...                                                    ...        ...
# 1599995  Contract awarded for Oh hyun junior high schoo...        114
# 1599996  MUMBAI: A young couple perched on the rocks by...        220
# 1599997  New York: American Civil Liberties Union has i...        468
# 1599998  FULL TEXT\n\n\n\nPublication Name: Metal & Min...        340
# 1599999  INDIAN DAILY STOCK REPORT\n\nTransformers & Re...       1431
#
#              country                                    content_cleaned
# 0          Australia  : Surgical instrument with modular end effecto...
# 1          Australia  Even basic data offers boost \n BETTER use can...
# 2          Australia  May 05, 2020 : issued patent titled" Image sen...
# 3        New Zealand  Green light for traffic safety projects \n LIV...
# 4          Australia  and to open center building \n, Wednesday 4 Ap...
# ...              ...                                                ...
# 1599995        India  Oh Hyun Junior High School Classroom Repair Wo...
# 1599996        India  Beach lifeguards spot marooned lovers kilomete...
# 1599997        India  Racial Justice and Civil Rights Organizations ...
# 1599998        India  Anhui Huiming Machinery Mfg Files Chinese Pate...
# 1599999        India  () underperforms 88% of the market July 13, 20...
#
# [1600000 rows x 5 columns]

# %%
# Free memory
del train_check

# %%
# Save another shuffled copy as .json
import io
train = train.sample(frac=1).reset_index(drop=True)
json_buffer = io.BytesIO(train.to_json(orient='records', lines=True).encode())

s3 = boto3.client('s3')
s3.upload_fileobj(json_buffer, "compressed-data-sample", "processed_train.json")

# %%
test
# Out:
#                                                     title  \
# 0                   Woman charged with reckless wounding'
# 1       Landscapes Below: Mapping and the New Science ...
# 2       TravelSky Technology - H Shares falls for a se...
# 3       American Eagle Outfitters chief operating offi...
# 4       Manusu's extraordinary comeback seals bream se...
# ...                                                   ...
# 399995                                   Swimming Teacher
# 399996  Jobs Growth in Last Fiscal was the Lowest in P...
# 399997  MAIRIN OHS & E CONSULTING PTY LTD Secures cont...
# 399998  Stephen Morgan ask the Secretary of State for ...
# 399999  UK Intellectual Property Office grants trade m...
#
#                                                   content  wordCount  \
# 0       AN Orient Point woman charged with stabbing he...         88
# 1       Cambridge: University of Cambridge, Australia ...        893
# 2       HONG KONG DAILY STOCK REPORT\n\nTravelSky Tech...       1226
# 3       American Eagle Outfitters (NYSE:AEO) Chief Ope...       1728
# 4       A last minute decision to enter the final qual...        304
# ...                                                   ...        ...
# 399995  Contract awarded for Swimming teacher \nDate o...         75
# 399996  CLSA REPORT\n\nThrough three quarters of FY18,...        230
# 399997  Australia, Dec. 23 -- Contract Id: 1812163\n\n...        142
# 399998  London: UK Parliament has issued the following...         95
# 399999  London:H&Y DIGITAL COMPANY LIMITED , has been ...        100
#
#           country                                    content_cleaned
# 0       Australia  Woman charged with reckless wounding' \n AN Or...
# 1         Belgium  Mapping and the New Science of Geology \n Camb...
# 2       Australia  falls for second consecutive day, two - day fa...
# 3       Australia  chief operating officer and executive vice pre...
# 4       Australia  's eback seals bream series grand final spot \...
# ...           ...                                                ...
# 399995      India  Swimming Teacher \n Contract awarded for Swimm...
# 399996      India  Jobs Growth in Last Fiscal was the Lowest in P...
# 399997      India  contract for \n, Dec. 23 -- Contract d : 18121...
# 399998      India  ask the Secretary of for defense, what discuss...
# 399999      India  grants trade mark" RevoRing" to H&Y DIGITAL CO...
#
# [400000 rows x 5 columns]

# %%
# Export Test
test.to_csv('s3://compressed-data-sample/processed_test.csv', index=False)

# %%
# Check if export correctly
start_time = time.time()
test_check = pd.read_csv('s3://compressed-data-sample/processed_test.csv', 
                          dtype={"wordCount": 'int16', "country":'category'})
end_time = time.time()
print(f'Loading Time: {end_time - start_time} seconds')
test_check
# Out:
# Loading Time: 146.13446378707886 seconds
#                                                     title  \
# 0                   Woman charged with reckless wounding'
# 1       Landscapes Below: Mapping and the New Science ...
# 2       TravelSky Technology - H Shares falls for a se...
# 3       American Eagle Outfitters chief operating offi...
# 4       Manusu's extraordinary comeback seals bream se...
# ...                                                   ...
# 399995                                   Swimming Teacher
# 399996  Jobs Growth in Last Fiscal was the Lowest in P...
# 399997  MAIRIN OHS & E CONSULTING PTY LTD Secures cont...
# 399998  Stephen Morgan ask the Secretary of State for ...
# 399999  UK Intellectual Property Office grants trade m...
#
#                                                   content  wordCount  \
# 0       AN Orient Point woman charged with stabbing he...         88
# 1       Cambridge: University of Cambridge, Australia ...        893
# 2       HONG KONG DAILY STOCK REPORT\n\nTravelSky Tech...       1226
# 3       American Eagle Outfitters (NYSE:AEO) Chief Ope...       1728
# 4       A last minute decision to enter the final qual...        304
# ...                                                   ...        ...
# 399995  Contract awarded for Swimming teacher \nDate o...         75
# 399996  CLSA REPORT\n\nThrough three quarters of FY18,...        230
# 399997  Australia, Dec. 23 -- Contract Id: 1812163\n\n...        142
# 399998  London: UK Parliament has issued the following...         95
# 399999  London:H&Y DIGITAL COMPANY LIMITED , has been ...        100
#
#           country                                    content_cleaned
# 0       Australia  Woman charged with reckless wounding' \n AN Or...
# 1         Belgium  Mapping and the New Science of Geology \n Camb...
# 2       Australia  falls for second consecutive day, two - day fa...
# 3       Australia  chief operating officer and executive vice pre...
# 4       Australia  's eback seals bream series grand final spot \...
# ...           ...                                                ...
# 399995      India  Swimming Teacher \n Contract awarded for Swimm...
# 399996      India  Jobs Growth in Last Fiscal was the Lowest in P...
# 399997      India  contract for \n, Dec. 23 -- Contract d : 18121...
# 399998      India  ask the Secretary of for defense, what discuss...
# 399999      India  grants trade mark" RevoRing" to H&Y DIGITAL CO...
#
# [400000 rows x 5 columns]

# %%
# Freeup memory
del test_check

# %%
# Save another shuffled copy as .json
test = test.sample(frac=1).reset_index(drop=True)
test.to_json('./processed_test.json', orient='records', lines=True)
s3 = boto3.resource('s3')
s3.Bucket('compressed-data-sample').upload_file('./processed_test.json','processed_test.json')
